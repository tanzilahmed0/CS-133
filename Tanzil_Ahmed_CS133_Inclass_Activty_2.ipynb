# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzilahmed0/CS-133/blob/main/Tanzil_Ahmed_CS133_Inclass_Activty_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings; warnings.filterwarnings("ignore")
import plotly.io as pio
pio.renderers.default = 'colab'



# plotly library
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px

# matplotlib
import matplotlib.pyplot as plt

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

uni_df = pd.read_csv('https://raw.githubusercontent.com/csbfx/advpy122-data/master/timesData.csv')
uni_df.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# ...

# %%
uni_df[uni_df.world_rank.str.contains('=')]
# Out:
#      world_rank                          university_name  \
# 1841        =39      University of California, San Diego
# 1842        =39  University of California, Santa Barbara
# 1846        =44          University of California, Davis
# 1847        =44                  University of Hong Kong
# 1849        =47                      Tsinghua University
# ...         ...                                      ...
# 1993       =190                           Boston College
# 1995       =193                 University of Luxembourg
# 1996       =193                     Texas A&M University
# 1998       =196                     Newcastle University
# 1999       =196        St George’s, University of London
#
#                        country  teaching international  research  citations  \
# 1841  United States of America      56.9          42.9      69.8       98.7
# 1842  United States of America      52.6          61.5      66.0       99.2
# ...

# %%
configure_plotly_browser_state()

fig = px.scatter(
    uni_df,
    x='teaching',
    y='citations',
    color='country',
    size='research',
    hover_name='university_name',
    hover_data=['world_rank', 'year'],
    title='Teaching Score vs Research Score for Universities from 2011 to 2016',
    labels={'citations': 'Research Influence Score', 'teaching': 'Teaching Score'},
    animation_frame='year'
)

fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# ...
